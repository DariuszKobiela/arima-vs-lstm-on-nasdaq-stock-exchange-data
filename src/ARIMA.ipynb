# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ROOT_PATH = "/content/drive/My Drive/PRACA_INŻYNIERSKA/COLAB_ARIMA"
ARIMA_SAMPLES_PATH = ROOT_PATH + '/ARIMA_samples'
ARIMA_PLOTS_PATH = ROOT_PATH + '/plots/ARIMA_plots'
ARIMA_MODEL_RESULTS = ROOT_PATH + '/models_results/ARIMA'

# %%
""" 
    Experiment 1 WORKING
    Predict [7, 14, 30, 60] days in ARIMA and choose p, q ranges
"""
# experiment_name = "Experiment_1_Predict_[7,14,30,60]_days_in_ARIMA_and_choose_p_q_ranges"
# experiment_id = 1
# output_window_size = [7, 14, 30, 60]  # always a list [7, 14, 30, 60]
# p_range = range(0, 8)  # list of possible p paramaters, range(0, 10)
# q_range = range(0, 8)  # list of possible q paramaters, range(0, 10)
# P_VALUE_PERCENT = '5%'

# arima_model = ARIMAModel(
#     experiment_name=experiment_name,
#     experiment_id=experiment_id,
#     output_window_size=output_window_size,
#     p_range=p_range,
#     q_range=q_range,
#     P_VALUE_PERCENT=P_VALUE_PERCENT
# )

# arima_model.ensure_stationarity_and_perform_forecast()
"""
    Experiment 7
    Predict 1 day in ARIMA
"""
# experiment_name = "Experiment_7_Predict_1_day_ARIMA"
# experiment_id = 7
# output_window_size = [1]  # always a list [7, 14, 30, 60]
# p_range = range(0, 3)  # list of possible p paramaters
# q_range = range(0, 3)  # list of possible q paramaters
# P_VALUE_PERCENT = '5%'

# # ARIMASeriesGenerator(
# #     series_averaging=False,
# #     use_log=True,
# #     save=True
# # ).generate_series()

# arima_model = ARIMAModel(
#     experiment_name=experiment_name,
#     experiment_id=experiment_id,
#     output_window_size=output_window_size,
#     p_range=p_range,
#     q_range=q_range,
#     P_VALUE_PERCENT=P_VALUE_PERCENT
# )
# arima_model.ensure_stationarity_and_perform_forecast()

"""
    Experiment 9
    Predict 30 days in ARIMA
"""
# experiment_name = "Experiment_9_Predict_30_days_ARIMA"
# experiment_id = 9
# output_window_size = [30]  # always a list [7, 14, 30, 60]
# p_range = range(0, 3)  # list of possible p paramaters
# q_range = range(0, 3)  # list of possible q paramaters
# P_VALUE_PERCENT = '5%'

# # ARIMASeriesGenerator(
# #     series_averaging=False,
# #     use_log=True,
# #     save=True
# # ).generate_series()

# arima_model = ARIMAModel(
#     experiment_name=experiment_name,
#     experiment_id=experiment_id,
#     output_window_size=output_window_size,
#     p_range=p_range,
#     q_range=q_range,
#     P_VALUE_PERCENT=P_VALUE_PERCENT
# )
# arima_model.ensure_stationarity_and_perform_forecast()
"""
    Experiment 11
    Predict 1 month in ARIMA
"""
# # PERIOD=365 dla danych dzienych (tyle dni jest w roku), PERIOD=12 dla danych miesięcznych (tyle jest miesięcy w roku)
# experiment_name = "Experiment_11_Predict_1_month_ARIMA"
# experiment_id = 11
# output_window_size = [1]  # always a list [7, 14, 30, 60]
# p_range = range(0, 3)  # list of possible p paramaters
# q_range = range(0, 3)  # list of possible q paramaters
# P_VALUE_PERCENT = '5%'
# series_averaging = True

# # ARIMASeriesGenerator(
# #     series_averaging=series_averaging,
# #     use_log=True,
# #     save=True
# # ).generate_series()

# arima_model = ARIMAModel(
#     experiment_name=experiment_name,
#     experiment_id=experiment_id,
#     output_window_size=output_window_size,
#     series_averaging=series_averaging,
#     p_range=p_range,
#     q_range=q_range,
#     P_VALUE_PERCENT=P_VALUE_PERCENT,
#     PERIOD=12
# )

# arima_model.ensure_stationarity_and_perform_forecast()

""" 
    Experiment 13 WORKING
    Predict [3] months in ARIMA (pq range wynika z eksperymentu 1)
"""
# #PERIOD=365 dla danych dzienych (tyle dni jest w roku), PERIOD=12 dla danych miesięcznych (tyle jest miesięcy w roku)
# experiment_name = "Experiment_13_Predict_3_months_in_ARIMA"
# experiment_id = 13
# output_window_size = [3] #always a list
# p_range = range(0, 3) #list of possible p paramaters
# q_range = range(0, 3) #list of possible q paramaters
# P_VALUE_PERCENT = '5%'
# series_averaging = True

# # ARIMASeriesGenerator(
# #     series_averaging=series_averaging,
# #     use_log=True,
# #     save=True
# # ).generate_series()

# arima_model = ARIMAModel(
#     experiment_name=experiment_name,
#     experiment_id=experiment_id,
#     output_window_size=output_window_size,
#     series_averaging=series_averaging,
#     p_range=p_range,
#     q_range=q_range,
#     P_VALUE_PERCENT=P_VALUE_PERCENT,
#     PERIOD=12
# )
# arima_model.ensure_stationarity_and_perform_forecast()
""" 
    Experiment 15 WORKING
    Predict [9] months in ARIMA 
"""
#PERIOD=365 dla danych dzienych (tyle dni jest w roku), PERIOD=12 dla danych miesięcznych (tyle jest miesięcy w roku)
experiment_name = "Experiment_15_Predict_9_months_in_ARIMA"
experiment_id = 15
output_window_size = [9] #always a list
p_range = range(0, 3) #list of possible p paramaters
q_range = range(0, 3) #list of possible q paramaters
P_VALUE_PERCENT = '5%'
series_averaging = True

# ARIMASeriesGenerator(
#     series_averaging=series_averaging,
#     use_log=True,
#     save=True
# ).generate_series()

arima_model = ARIMAModel(
    experiment_name=experiment_name,
    experiment_id=experiment_id,
    output_window_size=output_window_size,
    series_averaging=series_averaging,
    p_range=p_range,
    q_range=q_range,
    P_VALUE_PERCENT=P_VALUE_PERCENT,
    PERIOD=12
)
arima_model.ensure_stationarity_and_perform_forecast()
# Out:
# Predicting stock prices using ARIMA:   0%|          | 0/78 [00:00<?, ?it/s]
# ACN_series_averaging_True_use_log_True
# ACN
# company ACN_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC           -516.32
# BIC          -510.121
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC           -516.32
# BIC          -510.121
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:   1%|▏         | 1/78 [00:05<06:38,  5.18s/it]
# ABMD_series_averaging_True_use_log_True
# ABMD
# company ABMD_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -211.387
# BIC          -205.175
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -211.387
# BIC          -205.175
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:   3%|▎         | 2/78 [00:07<04:22,  3.46s/it]
# AMZN_series_averaging_True_use_log_True
# AMZN
# company AMZN_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -363.113
# BIC           -356.95
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -363.113
# BIC           -356.95
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:   4%|▍         | 3/78 [00:09<03:44,  2.99s/it]
# APA_series_averaging_True_use_log_True
# APA
# company APA_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(2,1,0)
# p                   2
# d                   1
# q                   0
# AIC          -162.322
# BIC          -153.766
# Name: 6, dtype: object
# ARIMA    ARIMA(2,1,0)
# p                   2
# d                   1
# q                   0
# AIC          -162.322
# BIC          -153.766
# Name: 6, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:   5%|▌         | 4/78 [00:12<03:28,  2.82s/it]
# ARCB_series_averaging_True_use_log_True
# ARCB
# company ARCB_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -139.279
# BIC          -134.324
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -139.279
# BIC          -134.324
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:   6%|▋         | 5/78 [00:14<03:16,  2.69s/it]
# AZN_series_averaging_True_use_log_True
# AZN
# company AZN_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(2,1,0)
# p                   2
# d                   1
# q                   0
# AIC          -232.892
# BIC           -225.98
# Name: 6, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -228.527
# BIC           -226.21
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:   8%|▊         | 6/78 [00:18<03:31,  2.94s/it]
# BA_series_averaging_True_use_log_True
# BA
# company BA_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(2,1,2)
# p                   2
# d                   1
# q                   2
# AIC          -342.641
# BIC          -327.203
# Name: 8, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -337.067
# BIC          -330.867
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:   9%|▉         | 7/78 [00:23<04:22,  3.70s/it]
# BAMXF_series_averaging_True_use_log_True
# BAMXF
# company BAMXF_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,2)
# p                   1
# d                   1
# q                   2
# AIC          -388.929
# BIC          -376.834
# Name: 5, dtype: object
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -387.147
# BIC          -381.086
# Name: 1, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  10%|█         | 8/78 [00:27<04:33,  3.91s/it]
# BKNG_series_averaging_True_use_log_True
# BKNG
# company BKNG_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -105.665
# BIC          -103.927
# Name: 0, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -105.665
# BIC          -103.927
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  12%|█▏        | 9/78 [00:30<03:55,  3.41s/it]
# BAC_series_averaging_True_use_log_True
# BAC
# company BAC_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -155.186
# BIC          -150.747
# Name: 3, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -155.176
# BIC          -152.957
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  13%|█▎        | 10/78 [00:33<03:48,  3.36s/it]
# BP_series_averaging_True_use_log_True
# BP
# company BP_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -378.668
# BIC          -372.505
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -378.668
# BIC          -372.505
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  14%|█▍        | 11/78 [00:36<03:28,  3.11s/it]
# CG_series_averaging_True_use_log_True
# CG
# company CG_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -259.636
# BIC          -254.181
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -259.636
# BIC          -254.181
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  15%|█▌        | 12/78 [00:38<03:08,  2.86s/it]
# CDEV_series_averaging_True_use_log_True
# CDEV
# company CDEV_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC           6.91093
# BIC            11.066
# Name: 1, dtype: object
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC           6.91093
# BIC            11.066
# Name: 1, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  17%|█▋        | 13/78 [00:40<02:54,  2.68s/it]
# CROX_series_averaging_True_use_log_True
# CROX
# company CROX_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(2,1,1)
# p                   2
# d                   1
# q                   1
# AIC          -170.823
# BIC          -158.448
# Name: 7, dtype: object
# ARIMA    ARIMA(1,1,1)
# p                   1
# d                   1
# q                   1
# AIC          -168.858
# BIC          -159.577
# Name: 4, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  18%|█▊        | 14/78 [00:44<03:16,  3.07s/it]
# COLM_series_averaging_True_use_log_True
# COLM
# company COLM_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -207.545
# BIC          -202.708
# Name: 1, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -205.432
# BIC          -203.001
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  19%|█▉        | 15/78 [00:48<03:23,  3.23s/it]
# CTAS_series_averaging_True_use_log_True
# CTAS
# company CTAS_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(2,1,1)
# p                   2
# d                   1
# q                   1
# AIC          -466.182
# BIC          -453.807
# Name: 7, dtype: object
# ARIMA    ARIMA(2,1,0)
# p                   2
# d                   1
# q                   0
# AIC          -466.126
# BIC          -456.844
# Name: 6, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  21%|██        | 16/78 [00:51<03:31,  3.41s/it]
# DXCM_series_averaging_True_use_log_True
# DXCM
# company DXCM_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,1)
# p                   1
# d                   1
# q                   1
# AIC          -216.968
# BIC          -207.668
# Name: 4, dtype: object
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -215.831
# BIC          -209.632
# Name: 1, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  22%|██▏       | 17/78 [00:55<03:33,  3.49s/it]
# DISH_series_averaging_True_use_log_True
# DISH
# company DISH_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -301.065
# BIC          -294.853
# Name: 3, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -298.394
# BIC          -295.288
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  23%|██▎       | 18/78 [00:58<03:26,  3.45s/it]
# FANG_series_averaging_True_use_log_True
# FANG
# company FANG_series_averaging_True_use_log_True
# Number of performed first diff = 0
# ARIMA    ARIMA(1,0,1)
# p                   1
# d                   0
# q                   1
# AIC          -140.406
# BIC           -132.36
# Name: 4, dtype: object
# ARIMA    ARIMA(1,0,1)
# p                   1
# d                   0
# q                   1
# AIC          -140.406
# BIC           -132.36
# Name: 4, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  24%|██▍       | 19/78 [01:01<03:07,  3.18s/it]
# FB_series_averaging_True_use_log_True
# FB
# company FB_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(2,1,1)
# p                   2
# d                   1
# q                   1
# AIC           -258.03
# BIC          -247.339
# Name: 7, dtype: object
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC           -257.23
# BIC          -251.885
# Name: 1, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  26%|██▌       | 20/78 [01:05<03:22,  3.49s/it]
# F_series_averaging_True_use_log_True
# F
# company F_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -297.611
# BIC          -291.906
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -297.611
# BIC          -291.906
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  27%|██▋       | 21/78 [01:08<03:00,  3.17s/it]
# GOOGL_series_averaging_True_use_log_True
# GOOGL
# company GOOGL_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -264.974
# BIC          -259.996
# Name: 3, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -263.154
# BIC          -260.666
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  28%|██▊       | 22/78 [01:11<02:58,  3.18s/it]
# FOXA_series_averaging_True_use_log_True
# FOXA
# company FOXA_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -242.789
# BIC          -237.598
# Name: 3, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC           -241.74
# BIC          -239.145
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  29%|██▉       | 23/78 [01:14<02:55,  3.19s/it]
# HNNMY_series_averaging_True_use_log_True
# HNNMY
# company HNNMY_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC           -340.32
# BIC          -334.509
# Name: 3, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -339.057
# BIC          -336.152
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  31%|███       | 24/78 [01:17<02:55,  3.24s/it]
# HMC_series_averaging_True_use_log_True
# HMC
# company HMC_series_averaging_True_use_log_True
# Number of performed first diff = 0
# ARIMA    ARIMA(1,0,0)
# p                   1
# d                   0
# q                   0
# AIC          -444.487
# BIC          -438.275
# Name: 3, dtype: object
# ARIMA    ARIMA(1,0,0)
# p                   1
# d                   0
# q                   0
# AIC          -444.487
# BIC          -438.275
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  32%|███▏      | 25/78 [01:20<02:37,  2.97s/it]
# IBM_series_averaging_True_use_log_True
# IBM
# company IBM_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -511.464
# BIC          -505.264
# Name: 3, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -509.585
# BIC          -506.485
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  33%|███▎      | 26/78 [01:23<02:40,  3.09s/it]
# IDXX_series_averaging_True_use_log_True
# IDXX
# company IDXX_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC           -383.43
# BIC          -377.218
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC           -383.43
# BIC          -377.218
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  35%|███▍      | 27/78 [01:26<02:35,  3.05s/it]
# JJSF_series_averaging_True_use_log_True
# JJSF
# company JJSF_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,1)
# p                   1
# d                   1
# q                   1
# AIC          -518.888
# BIC          -509.607
# Name: 4, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -518.238
# BIC          -512.038
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  36%|███▌      | 28/78 [01:30<02:46,  3.33s/it]
# INTC_series_averaging_True_use_log_True
# INTC
# company INTC_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -441.853
# BIC          -435.653
# Name: 3, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -438.758
# BIC          -435.658
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  37%|███▋      | 29/78 [01:34<02:45,  3.37s/it]
# KHC_series_averaging_True_use_log_True
# KHC
# company KHC_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -184.788
# BIC           -180.18
# Name: 3, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -184.781
# BIC          -182.477
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  38%|███▊      | 30/78 [01:37<02:39,  3.32s/it]
# JPM_series_averaging_True_use_log_True
# JPM
# company JPM_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -308.997
# BIC          -303.708
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -308.997
# BIC          -303.708
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  40%|███▉      | 31/78 [01:39<02:21,  3.02s/it]
# KDP_series_averaging_True_use_log_True
# KDP
# company KDP_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -121.434
# BIC          -119.771
# Name: 0, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -121.434
# BIC          -119.771
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  41%|████      | 32/78 [01:41<02:08,  2.80s/it]
# LAMR_series_averaging_True_use_log_True
# LAMR
# company LAMR_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(2,1,2)
# p                   2
# d                   1
# q                   2
# AIC          -286.257
# BIC          -270.788
# Name: 8, dtype: object
# ARIMA    ARIMA(2,1,2)
# p                   2
# d                   1
# q                   2
# AIC          -286.257
# BIC          -270.788
# Name: 8, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  42%|████▏     | 33/78 [01:46<02:25,  3.24s/it]
# KNDI_series_averaging_True_use_log_True
# KNDI
# company KNDI_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -84.4396
# BIC          -78.2768
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -84.4396
# BIC          -78.2768
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  44%|████▎     | 34/78 [01:48<02:11,  2.99s/it]
# LOGI_series_averaging_True_use_log_True
# LOGI
# company LOGI_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -324.587
# BIC          -318.399
# Name: 1, dtype: object
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -324.587
# BIC          -318.399
# Name: 1, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  45%|████▍     | 35/78 [01:50<02:01,  2.82s/it]
# MASI_series_averaging_True_use_log_True
# MASI
# company MASI_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -410.276
# BIC          -404.064
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -410.276
# BIC          -404.064
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  46%|████▌     | 36/78 [01:54<02:02,  2.92s/it]
# LYFT_series_averaging_True_use_log_True
# LYFT
# company LYFT_series_averaging_True_use_log_True
# Number of performed first diff = 0
# ARIMA    ARIMA(1,0,0)
# p                   1
# d                   0
# q                   0
# AIC          -23.2852
# BIC          -20.4828
# Name: 3, dtype: object
# ARIMA    ARIMA(1,0,0)
# p                   1
# d                   0
# q                   0
# AIC          -23.2852
# BIC          -20.4828
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  47%|████▋     | 37/78 [01:56<01:49,  2.68s/it]
# LPLA_series_averaging_True_use_log_True
# LPLA
# company LPLA_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -243.341
# BIC          -237.621
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -243.341
# BIC          -237.621
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  49%|████▊     | 38/78 [01:58<01:42,  2.57s/it]
# MCD_series_averaging_True_use_log_True
# MCD
# company MCD_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -605.588
# BIC          -599.388
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -605.588
# BIC          -599.388
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  50%|█████     | 39/78 [02:00<01:37,  2.51s/it]
# MRNA_series_averaging_True_use_log_True
# MRNA
# company MRNA_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,2)
# p                   1
# d                   1
# q                   2
# AIC          -11.0431
# BIC          -5.18014
# Name: 5, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -10.8551
# BIC          -7.80239
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  51%|█████▏    | 40/78 [02:05<01:54,  3.02s/it]
# MS_series_averaging_True_use_log_True
# MS
# company MS_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -294.243
# BIC          -288.539
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -294.243
# BIC          -288.539
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  53%|█████▎    | 41/78 [02:07<01:44,  2.82s/it]
# NEXT_series_averaging_True_use_log_True
# NEXT
# company NEXT_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -4.49444
# BIC          -2.56262
# Name: 0, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -4.49444
# BIC          -2.56262
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  54%|█████▍    | 42/78 [02:09<01:36,  2.68s/it]
# MSFT_series_averaging_True_use_log_True
# MSFT
# company MSFT_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC           -515.59
# BIC          -509.391
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC           -515.59
# BIC          -509.391
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  55%|█████▌    | 43/78 [02:12<01:32,  2.63s/it]
# NTR_series_averaging_True_use_log_True
# NTR
# company NTR_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -110.259
# BIC          -108.452
# Name: 0, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -110.259
# BIC          -108.452
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  56%|█████▋    | 44/78 [02:14<01:25,  2.52s/it]
# NTRS_series_averaging_True_use_log_True
# NTRS
# company NTRS_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -441.537
# BIC          -435.337
# Name: 3, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -439.587
# BIC          -436.487
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  58%|█████▊    | 45/78 [02:17<01:31,  2.77s/it]
# OAS_series_averaging_True_use_log_True
# OAS
# company OAS_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(2,1,2)
# p                   2
# d                   1
# q                   2
# AIC           57.3986
# BIC           71.8878
# Name: 8, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC           64.4373
# BIC           70.2626
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  59%|█████▉    | 46/78 [02:22<01:42,  3.21s/it]
# NXST_series_averaging_True_use_log_True
# NXST
# company NXST_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -140.188
# BIC          -133.988
# Name: 1, dtype: object
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -140.188
# BIC          -133.988
# Name: 1, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
#
# llungbox p_value=0.009109965699870111, boxpierce p_value=0.024780866036080988
# <class 'numpy.float64'>
# Predicting stock prices using ARIMA:  60%|██████    | 47/78 [02:25<01:39,  3.21s/it]
# NWSA_series_averaging_True_use_log_True
# NWSA
# company NWSA_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,1)
# p                   1
# d                   1
# q                   1
# AIC          -251.769
# BIC          -244.014
# Name: 4, dtype: object
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -250.247
# BIC          -245.077
# Name: 1, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  62%|██████▏   | 48/78 [02:29<01:42,  3.42s/it]
# PAA_series_averaging_True_use_log_True
# PAA
# company PAA_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(2,1,0)
# p                   2
# d                   1
# q                   0
# AIC          -177.617
# BIC          -169.598
# Name: 6, dtype: object
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -177.491
# BIC          -172.145
# Name: 1, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  63%|██████▎   | 49/78 [02:32<01:40,  3.46s/it]
# OZK_series_averaging_True_use_log_True
# OZK
# company OZK_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC           -61.914
# BIC          -58.6388
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC           -61.914
# BIC          -58.6388
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  64%|██████▍   | 50/78 [02:35<01:27,  3.12s/it]
# PCAR_series_averaging_True_use_log_True
# PCAR
# company PCAR_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -407.849
# BIC          -404.749
# Name: 0, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -407.849
# BIC          -404.749
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  65%|██████▌   | 51/78 [02:37<01:17,  2.88s/it]
# PAGP_series_averaging_True_use_log_True
# PAGP
# company PAGP_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(2,1,0)
# p                   2
# d                   1
# q                   0
# AIC          -74.9627
# BIC          -68.7814
# Name: 6, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -71.0855
# BIC          -69.0079
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  67%|██████▋   | 52/78 [02:40<01:18,  3.01s/it]
# PDCE_series_averaging_True_use_log_True
# PDCE
# company PDCE_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -125.592
# BIC          -120.191
# Name: 1, dtype: object
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -125.592
# BIC          -120.191
# Name: 1, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  68%|██████▊   | 53/78 [02:43<01:10,  2.82s/it]
# PEP_series_averaging_True_use_log_True
# PEP
# company PEP_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC           -626.66
# BIC           -623.56
# Name: 0, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC           -626.66
# BIC           -623.56
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  69%|██████▉   | 54/78 [02:45<01:05,  2.72s/it]
# PPC_series_averaging_True_use_log_True
# PPC
# company PPC_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -229.428
# BIC          -223.531
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -229.428
# BIC          -223.531
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  71%|███████   | 55/78 [02:48<01:00,  2.64s/it]
# QCOM_series_averaging_True_use_log_True
# QCOM
# company QCOM_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -397.912
# BIC            -391.7
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -397.912
# BIC            -391.7
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  72%|███████▏  | 56/78 [02:50<00:56,  2.58s/it]
# PYPL_series_averaging_True_use_log_True
# PYPL
# company PYPL_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -175.449
# BIC          -170.841
# Name: 3, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -174.692
# BIC          -172.388
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  73%|███████▎  | 57/78 [02:53<00:57,  2.75s/it]
# RACE_series_averaging_True_use_log_True
# RACE
# company RACE_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -177.931
# BIC          -173.522
# Name: 1, dtype: object
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -177.931
# BIC          -173.522
# Name: 1, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  74%|███████▍  | 58/78 [02:56<00:53,  2.65s/it]
# ROKU_series_averaging_True_use_log_True
# ROKU
# company ROKU_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -32.5172
# BIC          -28.7748
# Name: 3, dtype: object
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -32.5117
# BIC          -28.8115
# Name: 1, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  76%|███████▌  | 59/78 [02:59<00:54,  2.86s/it]
# SBUX_series_averaging_True_use_log_True
# SBUX
# company SBUX_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC           -231.43
# BIC          -226.743
# Name: 3, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -230.074
# BIC           -227.73
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  77%|███████▋  | 60/78 [03:03<00:59,  3.29s/it]
# SFM_series_averaging_True_use_log_True
# SFM
# company SFM_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,1)
# p                   1
# d                   1
# q                   1
# AIC          -222.553
# BIC          -214.829
# Name: 4, dtype: object
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC           -221.85
# BIC          -216.701
# Name: 1, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  78%|███████▊  | 61/78 [03:07<00:58,  3.45s/it]
# RYAAY_series_averaging_True_use_log_True
# RYAAY
# company RYAAY_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -375.579
# BIC          -369.379
# Name: 3, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -374.415
# BIC          -371.315
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  79%|███████▉  | 62/78 [03:11<00:55,  3.45s/it]
# SGEN_series_averaging_True_use_log_True
# SGEN
# company SGEN_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(2,1,0)
# p                   2
# d                   1
# q                   0
# AIC          -270.967
# BIC          -261.667
# Name: 6, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -270.078
# BIC          -266.972
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  81%|████████  | 63/78 [03:14<00:51,  3.45s/it]
# SGMS_series_averaging_True_use_log_True
# SGMS
# company SGMS_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(0,1,2)
# p                   0
# d                   1
# q                   2
# AIC          -144.405
# BIC          -135.124
# Name: 2, dtype: object
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -144.291
# BIC          -138.091
# Name: 1, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  82%|████████▏ | 64/78 [03:17<00:48,  3.45s/it]
# SMRT_series_averaging_True_use_log_True
# SMRT
# company SMRT_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -83.1374
# BIC          -77.1295
# Name: 1, dtype: object
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -83.1374
# BIC          -77.1295
# Name: 1, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  83%|████████▎ | 65/78 [03:20<00:40,  3.11s/it]
# SHOO_series_averaging_True_use_log_True
# SHOO
# company SHOO_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC           -63.235
# BIC           -60.068
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC           -63.235
# BIC           -60.068
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  85%|████████▍ | 66/78 [03:22<00:34,  2.88s/it]
# SKYW_series_averaging_True_use_log_True
# SKYW
# company SKYW_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(2,1,2)
# p                   2
# d                   1
# q                   2
# AIC          -243.597
# BIC          -228.159
# Name: 8, dtype: object
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -238.571
# BIC          -232.384
# Name: 1, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  86%|████████▌ | 67/78 [03:27<00:37,  3.42s/it]
# TM_series_averaging_True_use_log_True
# TM
# company TM_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -499.027
# BIC          -492.828
# Name: 3, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -497.506
# BIC          -494.406
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  87%|████████▋ | 68/78 [03:30<00:34,  3.43s/it]
# SNY_series_averaging_True_use_log_True
# SNY
# company SNY_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -539.346
# BIC          -533.134
# Name: 3, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -536.288
# BIC          -533.182
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  88%|████████▊ | 69/78 [03:34<00:30,  3.40s/it]
# UAL_series_averaging_True_use_log_True
# UAL
# company UAL_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -203.846
# BIC          -198.096
# Name: 3, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -201.806
# BIC          -198.931
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  90%|████████▉ | 70/78 [03:37<00:26,  3.35s/it]
# UPS_series_averaging_True_use_log_True
# UPS
# company UPS_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -463.104
# BIC          -456.904
# Name: 3, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -461.701
# BIC          -458.602
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  91%|█████████ | 71/78 [03:40<00:23,  3.31s/it]
# UL_series_averaging_True_use_log_True
# UL
# company UL_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -569.106
# BIC          -562.906
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -569.106
# BIC          -562.906
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  92%|█████████▏| 72/78 [03:42<00:18,  3.01s/it]
# URBN_series_averaging_True_use_log_True
# URBN
# company URBN_series_averaging_True_use_log_True
# Number of performed first diff = 0
# ARIMA    ARIMA(1,0,1)
# p                   1
# d                   0
# q                   1
# AIC          -301.274
# BIC          -291.974
# Name: 4, dtype: object
# ARIMA    ARIMA(1,0,1)
# p                   1
# d                   0
# q                   1
# AIC          -301.274
# BIC          -291.974
# Name: 4, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  94%|█████████▎| 73/78 [03:45<00:14,  2.82s/it]
# V_series_averaging_True_use_log_True
# V
# company V_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC          -270.198
# BIC          -265.485
# Name: 3, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -267.971
# BIC          -265.615
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  95%|█████████▍| 74/78 [03:49<00:13,  3.36s/it]
# VLKAF_series_averaging_True_use_log_True
# VLKAF
# company VLKAF_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -323.099
# BIC          -317.216
# Name: 1, dtype: object
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC          -323.099
# BIC          -317.216
# Name: 1, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  96%|█████████▌| 75/78 [03:52<00:09,  3.10s/it]
# WDAY_series_averaging_True_use_log_True
# WDAY
# company WDAY_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -220.391
# BIC          -217.709
# Name: 0, dtype: object
# ARIMA    ARIMA(0,1,0)
# p                   0
# d                   1
# q                   0
# AIC          -220.391
# BIC          -217.709
# Name: 0, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  97%|█████████▋| 76/78 [03:54<00:05,  2.82s/it]
# WKHS_series_averaging_True_use_log_True
# WKHS
# company WKHS_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC           57.5391
# BIC           62.2006
# Name: 1, dtype: object
# ARIMA    ARIMA(0,1,1)
# p                   0
# d                   1
# q                   1
# AIC           57.5391
# BIC           62.2006
# Name: 1, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA:  99%|█████████▊| 77/78 [03:56<00:02,  2.63s/it]
# ZM_series_averaging_True_use_log_True
# ZM
# company ZM_series_averaging_True_use_log_True
# Number of performed first diff = 1
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC           -23.459
# BIC          -20.7945
# Name: 3, dtype: object
# ARIMA    ARIMA(1,1,0)
# p                   1
# d                   1
# q                   0
# AIC           -23.459
# BIC          -20.7945
# Name: 3, dtype: object
#
# Duration of choosing the best ARIMA model: 0h 0min 0s
# Predicting stock prices using ARIMA: 100%|██████████| 78/78 [03:58<00:00,  3.06s/it]
# arima_params [(1, 1, 0), (2, 1, 0), (0, 1, 0), (2, 1, 2), (1, 1, 2), (0, 1, 1), (2, 1, 1), (1, 1, 1), (1, 0, 1), (1, 0, 0), (0, 1, 2)]
# Duration of choosing the best ARIMA model: 0h 0min 14s
# MSE TEST SCORE for ARIMA((1, 1, 0)) for period=9: 1396.251884280342
# MAPE TEST SCORE for ARIMA((1, 1, 0)) for period=9: 5.981116667310616
# Duration of choosing the best ARIMA model: 0h 0min 1s
# MSE TEST SCORE for ARIMA((2, 1, 0)) for period=9: 43.33989458975767
# MAPE TEST SCORE for ARIMA((2, 1, 0)) for period=9: 5.952930395981241
# Duration of choosing the best ARIMA model: 0h 0min 9s
# MSE TEST SCORE for ARIMA((0, 1, 0)) for period=9: 1223.4093561299617
# MAPE TEST SCORE for ARIMA((0, 1, 0)) for period=9: 4.841776923901037
# Duration of choosing the best ARIMA model: 0h 0min 1s
# MSE TEST SCORE for ARIMA((2, 1, 2)) for period=9: 310.06157882838687
# MAPE TEST SCORE for ARIMA((2, 1, 2)) for period=9: 11.976129661914161
# Duration of choosing the best ARIMA model: 0h 0min 0s
# MSE TEST SCORE for ARIMA((1, 1, 2)) for period=9: 1691.9838818430994
# MAPE TEST SCORE for ARIMA((1, 1, 2)) for period=9: 11.005019112182149
# Duration of choosing the best ARIMA model: 0h 0min 5s
# MSE TEST SCORE for ARIMA((0, 1, 1)) for period=9: 419.5238625186377
# MAPE TEST SCORE for ARIMA((0, 1, 1)) for period=9: 10.472381744851583
# Duration of choosing the best ARIMA model: 0h 0min 0s
# MSE TEST SCORE for ARIMA((2, 1, 1)) for period=9: 119.46469153754715
# MAPE TEST SCORE for ARIMA((2, 1, 1)) for period=9: 4.071512773221753
# Duration of choosing the best ARIMA model: 0h 0min 1s
# MSE TEST SCORE for ARIMA((1, 1, 1)) for period=9: 626.2549503430707
# MAPE TEST SCORE for ARIMA((1, 1, 1)) for period=9: 5.794426564966438
# Duration of choosing the best ARIMA model: 0h 0min 0s
# MSE TEST SCORE for ARIMA((1, 0, 1)) for period=9: 56.90571322559566
# MAPE TEST SCORE for ARIMA((1, 0, 1)) for period=9: 7.961345620082221
# Duration of choosing the best ARIMA model: 0h 0min 0s
# MSE TEST SCORE for ARIMA((1, 0, 0)) for period=9: 17.42866286619941
# MAPE TEST SCORE for ARIMA((1, 0, 0)) for period=9: 5.485881943497711
# Duration of choosing the best ARIMA model: 0h 0min 0s
# MSE TEST SCORE for ARIMA((0, 1, 2)) for period=9: 56.96820549791423
# MAPE TEST SCORE for ARIMA((0, 1, 2)) for period=9: 9.50431507001689
#            timestamp experiment_id  ... exec_runtime_hours           exec_runtime
# 0   2021-11-27_09_48            15  ...        0h 0min 14s 0 days 00:00:14.479656
# 1   2021-11-27_09_48            15  ...         0h 0min 1s 0 days 00:00:01.611488
# 2   2021-11-27_09_48            15  ...         0h 0min 9s 0 days 00:00:09.022873
# 3   2021-11-27_09_48            15  ...         0h 0min 1s 0 days 00:00:01.355106
# 4   2021-11-27_09_48            15  ...         0h 0min 0s 0 days 00:00:00.651836
# 5   2021-11-27_09_48            15  ...         0h 0min 5s 0 days 00:00:05.425125
# 6   2021-11-27_09_48            15  ...         0h 0min 0s 0 days 00:00:00.959502
# 7   2021-11-27_09_48            15  ...         0h 0min 1s 0 days 00:00:01.846883
# 8   2021-11-27_09_48            15  ...         0h 0min 0s 0 days 00:00:00.696245
# 9   2021-11-27_09_48            15  ...         0h 0min 0s 0 days 00:00:00.754179
# 10  2021-11-27_09_48            15  ...         0h 0min 0s 0 days 00:00:00.249078
#
# [11 rows x 12 columns]

# %%
import math

from pandas import DateOffset
from tqdm import tqdm

# set global random_seed
import tensorflow as tf

tf.random.set_seed(7)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense, Dropout

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.python.keras.callbacks import EarlyStopping
import datetime as dt

# ARIMA imports
import pandas as pd
import glob
import numpy as np
import glob
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
from statsmodels.tsa.stattools import adfuller
#from statsmodels.tsa.arima.model import ARIMA  # here the arima.model instead of arima_model
from statsmodels.tsa.statespace.sarimax import SARIMAX

import warnings

warnings.filterwarnings("ignore")
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA', FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA', FutureWarning)
# warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
import statsmodels.api as sm
from datetime import datetime
import os

# from statsmodels.tsa.arima_model import ARIMA #usually I used this version, but it will be deprecated
# C:\Users\Darek_PC\miniconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.

# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.

# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:

# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA', FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA', FutureWarning)
# warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

class Model:
    def __init__(self, experiment_name):
        self.experiment_name = experiment_name


class ARIMAModel(Model):
    def __init__(self, experiment_name, experiment_id, output_window_size, series_averaging=False, p_range=range(0, 5), q_range=range(0, 5),
                 PERIOD=365,
                 P_VALUE_PERCENT='5%', REGRESSION_TYPE_FOR_DF_TEST='c', AUTOLAG_FOR_DF_TEST='AIC',
                 LJUNGBOX_BOXPIERCE_LAGS=24):
        super().__init__(experiment_name)
        self.experiment_name = experiment_name
        self.experiment_id = experiment_id
        self.series_averaging = series_averaging
        """
        https://predictivehacks.com/time-series-decomposition/
        Our data here are aggregated by days. 
        The period we want to analyze is by year so that’s why we set the period to 365.
        """
        self.period = PERIOD
        self.p_range = p_range
        self.q_range = q_range
        self.p_value_percent = P_VALUE_PERCENT  # ['1%', '5%', '10%']
        self.p_value = float(P_VALUE_PERCENT.strip('%')) / 100.0
        """
        'c' : constant only, the most common choice (default value)
        'ct' : constant and trend.
        'ctt' : constant, and linear and quadratic trend
        'n' : no constant, no trend
        """
        self.regression_type_for_df_test = REGRESSION_TYPE_FOR_DF_TEST  # ['c', 'ct', 'ctt', 'n']
        self.autolag_for_df_test = AUTOLAG_FOR_DF_TEST  # ['AIC', 'BIC']
        self.ljungbox_boxpierce_lags = LJUNGBOX_BOXPIERCE_LAGS  # for NOT seasonal series number of lags is always 24
        self.periods_to_forecast = output_window_size  # a list like [6, 10, 30]

    def ensure_stationarity_and_perform_forecast(self):
        COLUMN_NAMES = ['company', 'experiment_id', 'model_name', 'p', 'd', 'q', 'fc_period', 'MSE', 'MAPE',
                        'exec_time_hours', 'exec_time']
        mse_df = pd.DataFrame(columns=COLUMN_NAMES)
        if self.series_averaging == True:
            paths = glob.glob(ARIMA_SAMPLES_PATH + "/*series_averaging_True_use_log_True.csv")
        else:
            paths = glob.glob(ARIMA_SAMPLES_PATH + "/*series_averaging_False_use_log_True.csv")
        # tmp_counter = 0
        for path in tqdm(paths, desc="Predicting stock prices using ARIMA"):
            # SET PLOTS STYLE
            plt.style.use('fivethirtyeight')
            plt.style.use('seaborn-bright')
            # extract company name for further plots
            splitted = path.split("/content/drive/My Drive/PRACA_INŻYNIERSKA/COLAB_ARIMA/ARIMA_samples/")[-1]
            #print(splitted)
            company = splitted.split(".csv")[0]
            print(company)
            company_short = company.split("_")[0]
            print(company_short)
            print("company", company)
            # print("company_short", company_short)
            df = pd.read_csv(path, index_col=0)
            df.timestamp = pd.to_datetime(df.timestamp)
            df.sort_values(by='timestamp', inplace=True)
            # print(df)
            # NO LONGER NEEDED: calculate weight for the given company
            # weight = df.avg_price.max() - df.avg_price.min()
            # print(f'{company_short} weight: {weight} \n')
            # 1. Time Series decomposition
            #try:
            self.decompose_time_series(df.copy(), company, company_short, self.period)
            # except ValueError:
            #     print(f"Exception: Decomposition not possible - too short series {company}")
            # except:
            #     print(f"Some error occurred for company {company}")
            # 3. Stationarity
            test_statistic, critical_value = self.perform_df_test(df.avg_price, self.regression_type_for_df_test,
                                                                  self.autolag_for_df_test, self.p_value_percent)
            # print(test_statistic, critical_value)
            number_of_first_diff = 0
            if test_statistic > critical_value:
                while (test_statistic > critical_value):
                    number_of_first_diff += 1
                    df_diff = self.perform_first_difference(df.copy(), number_of_first_diff, company, company_short)
                    test_statistic, critical_value = self.perform_df_test(df_diff.diff_price,
                                                                          self.regression_type_for_df_test,
                                                                          self.autolag_for_df_test,
                                                                          self.p_value_percent)
                    #print(f"Number of first diff = {number_of_first_diff}")
                    #print(test_statistic, critical_value)
                    if number_of_first_diff > 2:
                        print(f"WARNING! SOMETHING IS WRONG - THERE WAS {number_of_first_diff} first difference")
                        test_statistic = test_statistic + 5000
                        print("Abandoning {company} company!")
            if number_of_first_diff > 2:
                continue
            else:
                # if no first diff performed - we still need df_diff for further computations
                df_diff = df.copy()
                df_diff = df_diff.rename(columns={'avg_price': 'diff_price'})
            print(f"Number of performed first diff = {number_of_first_diff}")
            # print('Original dataframe', df)
            # print('First differenced dataframe', df_diff)
            # EXTRA STEP: SAVE ACF and PACF chart
            """
            They are used to choose p, q paramaters: usually we count up to 10th tab, how many of them is above the significance level. 
            They are also used to check stationarity: if the tabs come down quickly, then this suggests that the series should be stationary.
            """
            try:
                self.create_acf_pacf_charts(df_diff.diff_price, self.ljungbox_boxpierce_lags, 'timeseries', company,
                                            company_short, use_pq=False)
            except:
                print(f"Exception: not possible to create acf_pacf_charts for {company}")
            # 4. Automatically choose ARIMA parameters p, d, q (measure "training" time)
            """
            IMPORTANT!! I PERFORM ARIMA ON DIFFERENCED AND LOGGED VALUES!!
            Only log values was not enough (not stationary).
            """
            start_time = datetime.now()
            d = number_of_first_diff
            p_range = self.p_range  # range(0, 10)
            q_range = self.q_range  # range(0, 10)
            # POSSIBLE ARIMA COMBINATIONS - ANALIZA AUTOMATYCZNA
            arima_combinations_list = []
            aic_results_list = []
            bic_results_list = []
            p_parameter_list = []
            d_parameter_list = []
            q_parameter_list = []
            # hqic_results_list = []
            for p in p_range:
                for q in q_range:
                    results = SARIMAX(endog=df_diff.diff_price, order=(p, d, q),
                                    enforce_stationarity=False).fit()  # method='innovations_mle'; disp=-1
                    # df_diff.diff_price, initialization='approximate_diffuse'
                    # , enforce_stationarity=False should help
                    # https://github.com/statsmodels/statsmodels/issues/5459
                    arima_combinations_list.append(f"ARIMA({p},{d},{q})")
                    p_parameter_list.append(p)
                    d_parameter_list.append(d)
                    q_parameter_list.append(q)
                    aic_results_list.append(results.aic)
                    bic_results_list.append(results.bic)
                    # hqic_results_list.append(results.hqic)
            #print(aic_results_list)
            #print(bic_results_list)
            # print(hqic_results_list)
            auto_ARIMA_df = pd.DataFrame(list(zip(arima_combinations_list,
                                                  p_parameter_list,
                                                  d_parameter_list,
                                                  q_parameter_list,
                                                  aic_results_list,
                                                  bic_results_list)),
                                         columns=['ARIMA', 'p', 'd', 'q', 'AIC', 'BIC'])
            #print("auto_ARIMA_df", auto_ARIMA_df)
            # Save model results to CSV
            auto_ARIMA_df.to_csv(f'{ARIMA_MODEL_RESULTS}/{self.experiment_name}_{company}_ARIMA_parameters.csv')
            #auto_ARIMA_df.to_csv(ARIMA_MODEL_RESULTS + '/{0}_ARIMA_parameters.csv'.format(company))

            #print('Best ARIMA according to AIC criterium:')
            best_ARIMA_aic = auto_ARIMA_df.sort_values(by=['AIC']).iloc[0]
            print(best_ARIMA_aic)
            p_best_aic = best_ARIMA_aic[1]
            q_best_aic = best_ARIMA_aic[3]

            #print('\nBest ARIMA according to BIC criterium:')
            best_ARIMA_bic = auto_ARIMA_df.sort_values(by=['BIC']).iloc[0]
            print(best_ARIMA_bic)
            p_best_bic = best_ARIMA_bic[1]
            q_best_bic = best_ARIMA_bic[3]

            best_pq_list = []
            best_pq_list.append((p_best_aic, q_best_aic))
            if ((p_best_aic, q_best_aic) != (p_best_bic, q_best_bic)):
                best_pq_list.append((p_best_bic, q_best_bic))
            # measure "training" time
            end_time = datetime.now()
            execution_time = end_time - start_time
            exec_hours = execution_time.seconds // 3600
            exec_minutes = (execution_time.seconds % 3600) // 60
            exec_seconds = (execution_time.seconds % 3600) % 60
            execution_time_h = f"{exec_hours}h {exec_minutes}min {exec_seconds}s"
            print(f"\nDuration of choosing the best ARIMA model: {execution_time_h}\n")
            # 5. Check the autocorrelations for residuals (white noise)
            for pq in best_pq_list:
                #try:
                lb_p_value, bp_p_value, residuals = self.perform_ljungbox_boxpierce(df.avg_price, int(pq[0]), d,
                                                                                    int(pq[1]),
                                                                                    self.ljungbox_boxpierce_lags)
                self.create_acf_pacf_charts(residuals, self.ljungbox_boxpierce_lags, 'residuals', company,
                                            company_short, use_pq=True, pq=pq)
                if (self.p_value > lb_p_value) or (self.p_value > bp_p_value):
                    print(f"llungbox p_value={lb_p_value[0]}, boxpierce p_value={bp_p_value[0]}")
                    print(type(lb_p_value[0]))
                    with open(f'{ARIMA_PLOTS_PATH}/{self.experiment_name}_{company_short}_residuals_p_{pq[0]}_q_{pq[1]}_plot_ACF_and_PACF.txt', 'a') as f:
                        f.write(f'{self.experiment_name},{company_short},residuals p={pq[0]},q={pq[1]},chosen p_value level={self.p_value},llungbox p_value={round(lb_p_value[0], 4)}, boxpierce p_value={round(bp_p_value[0], 4)}\n')
                        f.close()
                    # img = mpimg.imread(f'{ARIMA_PLOTS_PATH}/{self.experiment_name}_{company_short}_residuals_p_{pq[0]}_q_{pq[1]}_plot_ACF_and_PACF.png', format='png')
                    # #img = mpimg.imread(ARIMA_PLOTS_PATH + '/{0}_{1}_plot_ACF_and_PACF.png'.format(company, 'residuals'), format='png')
                    # # Output Images
                    # fig = plt.figure(figsize=(18, 12), dpi=140)
                    # plt.axis('off')  # turn off axis
                    # plt.title(f'Please decide, if the residuals are white noise.\n \
                    #     When you are ready, close the window and choose. \n \
                    #     Llungbox p_value = {round(lb_p_value, 4)}, Boxpierce p_value = {round(bp_p_value, 4)}. \n \
                    #     Chosen p_value level is {self.p_value}')
                    # plt.imshow(img)
                    # plt.show()
                    # # USER HAS TO CHOOSE, IF THE SERIES IS STATIONARY
                    # # TODO: implement tkinter, when this will be a python script
                    # answer = input('Do the residuals approximate white noise? [y/n]: ')
                    # if answer == 'n':
                    #     print('IT IS NOT POSSIBLE TO PERFORM THE FORECAST!\n')
                    #     print('THE MODEL IS ABANDONED!\n')
                    #     # TODO: implement some info about this to log file
                    #     continue  # this will end this for loop iteration
                # except ValueError:
                #     print(f"An ljungbox-boxpierce exception occurred for company {company}, parameters pq {pq}")
                # except:
                #     print(f"Some error occurred for company {company}, parameters pq {pq} during white noise checking")
                # The residuals of the model are white noise. We can proceed.
                # 6. PERFORM ARIMA FORECAST
                try:
                    for period in self.periods_to_forecast:
                        # Prepare train and test set
                        # df.index = df.timestamp
                        # Używamy wartości tylko po logarytmie, żeby inwestor miał prawdziwe wartości (exp(log_value))
                        train = df.avg_price[:-period]
                        test = df.avg_price[-period:]
                        test_timestamp = df.timestamp[-period:]
                        train_timestamp = df.timestamp[:-period]

                        # define lists to be predicted
                        history = [x for x in train]
                        future = [x for x in test]
                        predictions = []
                        se_list = []
                        lower_series_list = []
                        upper_series_list = []

                        # Train the model separately for every prediction
                        # https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/
                        for per in range(period):
                            model = SARIMAX(endog=history, order=(pq[0], d, pq[1]))
                            fitted = model.fit()  # transparams=False
                            fcast_res = fitted.get_forecast(steps=1, alpha=self.p_value)
                            # print("Forecast results for per={0}:".format(per))
                            # print(fcast_res.summary_frame())
                            fc = fcast_res.summary_frame()['mean'][0]
                            predictions.append(fc)
                            se = fcast_res.summary_frame()['mean_se'][0]
                            se_list.append(se)
                            lower_series = fcast_res.summary_frame()['mean_ci_lower'][0]
                            lower_series_list.append(lower_series)
                            upper_series = fcast_res.summary_frame()['mean_ci_upper'][0]
                            upper_series_list.append(upper_series)
                            # append to the test set
                            obs = future[per]
                            history.append(obs)
                            # print(f"Forecast results for per={per}: predicted={fcast_res.summary_frame()['mean'].values[0]}, expected={obs}")
                            # print('predicted=%f, expected=%f' % (fcast_res.summary_frame()['mean'], obs))
                        # # print predictions
                        # prediction_df = pd.DataFrame(
                        #     {'prediction': predictions,
                        #      'se': se_list,
                        #      'lower_series': lower_series_list,
                        #      'upper_series': upper_series_list
                        #      })
                        # print(prediction_df)
                        # print model summary
                        # print("Summary of the last predicted model", fitted.summary())
                        # save summary to file
                        _path = f'{ARIMA_MODEL_RESULTS}/{self.experiment_name}_{company}_ARIMA({pq[0]}{d}{pq[1]})_model_summary_period_{period}.csv'
                        with open(_path, 'w') as f:
                            f.write(fitted.summary().as_csv())

                        # Test the model (perform forecast)
                        # https://www.statsmodels.org/dev/examples/notebooks/generated/statespace_forecasting.html
                        # fcast_res = fitted.get_forecast(steps=period, alpha=P_VALUE)  # 3 okresy do przodu, 95% conf
                        # fc = fcast_res.summary_frame()['mean']
                        # se = fcast_res.summary_frame()['mean_se']
                        # lower_series = fcast_res.summary_frame()['mean_ci_lower']
                        # upper_series = fcast_res.summary_frame()['mean_ci_upper']
                        # get_forecast instead of forecast
                        # se - błąd standardowy, standard error
                        # fc - forecast
                        # conf - poziom ufności, confidence interval
                        # Make as pandas series - NOT NEEDED ANY MORE
                        # fc_series = pd.Series(fc, index=test.index)
                        # lower_series = pd.Series(conf[:, 0], index=test.index)
                        # upper_series = pd.Series(conf[:, 1], index=test.index)

                        # Make plots
                        self.create_prediction_plot(df, train, test, predictions, lower_series_list, upper_series_list,
                                                    period, train_timestamp, test_timestamp, company, company_short,
                                                    p=pq[0], d=d, q=pq[1])
                        self.create_zoomed_prediction_plot(df, test, predictions, lower_series_list, upper_series_list,
                                                           period, test_timestamp, company, company_short, p=pq[0], d=d,
                                                           q=pq[1])
                        # Calculate MSE
                        mse = np.mean(np.square(np.exp(predictions) - np.exp(test.values)))
                        # Calculate MAPE
                        mape = np.mean(np.abs((np.exp(test.values) - np.exp(predictions)) / np.exp(test.values))) * 100
                        # def mean_absolute_percentage_error(y_true, y_pred):
                        #    y_true, y_pred = np.array(y_true), np.array(y_pred)
                        #    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

                        # 7. SAVE RESULTS
                        # 7.1 results of specific experiment
                        prediction_df = pd.DataFrame(
                            {'company': company_short,
                             'real_value': test.values,
                             'prediction': predictions,
                             'se': se_list,
                             'lower_series': lower_series_list,
                             'upper_series': upper_series_list
                             })
                        # save prediction results:
                        prediction_df.to_csv(
                            f'{ARIMA_MODEL_RESULTS}/{self.experiment_name}_{company}_ARIMA({pq[0]}{d}{pq[1]})_period_{period}_prediction_results.csv')
                        # forecast_results = pd.DataFrame(zip(test.values, predictions), columns=['True_Value', 'ARIMA_forecast'])
                        # forecast_results['Company'] = company_short
                        # forecast_results.to_csv(ARIMA_MODEL_RESULTS + f'/{company}_forecast_results_ARIMA({pq[0]},{d},{pq[1]})_period_{period}.csv')
                        # 7.2 MASTER TABLE
                        # [company, ARIMA, p,d,q , period, mse]
                        arima_tmp = f'ARIMA({pq[0]},{d},{pq[1]})'
                        mse_list = [company_short, self.experiment_id, arima_tmp, pq[0], d, pq[1], period, mse, mape,
                                    execution_time_h, execution_time]
                        mse_df = mse_df.append(pd.Series(mse_list, index=mse_df.columns), ignore_index=True)
                        # print(mse_df)
                        ### END OF LOOP ###
                except ValueError:
                    print(
                        f"An ARIMA prediction exception occurred for company {company}, parameters pq {pq}, period {period}")
                except:
                    print(f"Some error occurred for company {company}, parameters pq {pq}, period {period} during prediction")
            # delete tmp_counter
            # tmp_counter += 1
            # print("counter", tmp_counter)
            # if tmp_counter == 3:
            #    break
        # 7.3 After all experiments
        saving_time = datetime.now().strftime('%Y-%m-%d_%H_%M_%S')
        mse_df.to_csv(ARIMA_MODEL_RESULTS + f'/SEMI_MASTER_TABLE_forecast_results_{saving_time}.csv')
        #print(mse_df)
        # 8. MODEL RESULTS, MASTER TABLE WITH ALL THE DATA
        MASTER_COLUMN_NAMES = ['timestamp', 'experiment_id', 'experiment_desc', 'model_name', 'p', 'd', 'q',
                               'fc_period', 'MSE', 'MAPE', 'exec_runtime_hours', 'exec_runtime']
        master_table_df = pd.DataFrame(columns=MASTER_COLUMN_NAMES)
        ###
        arima_params = []
        for index, row in mse_df.iterrows():
            tmp = (row['p'], row['d'], row['q'])
            if tmp not in arima_params:
                arima_params.append(tmp)
        print("arima_params", arima_params)
        # mse_error_list = []
        tmp_df = mse_df.copy()
        for period in self.periods_to_forecast:
            second_df = tmp_df[tmp_df['fc_period'] == period]
            for pdq in arima_params:
                third_df = second_df[
                    (second_df['p'] == pdq[0]) & (second_df['d'] == pdq[1]) & (second_df['q'] == pdq[2])]
                #print("third_df['MSE']", third_df['MSE'])
                mse_error = third_df['MSE'].mean()
                # print('mse_error', mse_error)
                # print("third_df['MAPE']", third_df['MAPE'])
                mape_error = third_df['MAPE'].mean()
                #print('mape_error', mape_error)
                #print("third_df['exec_time']", third_df['exec_time'])
                exec_time = third_df['exec_time'].sum()  # sum rather than mean() execution time
                #print('exec_time', exec_time)
                exec_hours = exec_time.seconds // 3600
                exec_minutes = (exec_time.seconds % 3600) // 60
                exec_seconds = (exec_time.seconds % 3600) % 60
                exec_time_h = f"{exec_hours}h {exec_minutes}min {exec_seconds}s"
                print(f"Duration of choosing the best ARIMA model: {exec_time_h}")
                print(f'MSE TEST SCORE for ARIMA({pdq}) for period={period}: {mse_error}')
                print(f'MAPE TEST SCORE for ARIMA({pdq}) for period={period}: {mape_error}')
                master_table_values = [datetime.now().strftime('%Y-%m-%d_%H_%M'),
                                       self.experiment_id,
                                       self.experiment_name,
                                       f'ARIMA{pdq}',
                                       pdq[0],
                                       pdq[1],
                                       pdq[2],
                                       period,
                                       mse_error,
                                       mape_error,
                                       exec_time_h,
                                       exec_time]
                master_table_df = master_table_df.append(pd.Series(master_table_values, index=master_table_df.columns),
                                                         ignore_index=True)
        # 9. SAVE MASTER TABLE WITH ALL THE DATA
        print(master_table_df)
        master_file = ARIMA_MODEL_RESULTS + f'/MASTER_TABLE.csv'
        file_exists = os.path.isfile(master_file)
        if not file_exists:
            with open(master_file, 'x') as f:
                master_table_df.to_csv(master_file)
                f.close()
        else:
            master_table_df.to_csv(master_file, mode='a', header=None)
        ### END OF FUNCTION ###

    def decompose_time_series(self, df, company, company_short, period):
        """
        sm.tsa.seasonal_decompose returns a DecomposeResult.
        This has attributes observed, trend, seasonal and resid, which are pandas series.
        You may plot each of them using the pandas plot functionality.
        """
        df.set_index('timestamp', inplace=True)
        df.index = pd.to_datetime(df.index)
        result = seasonal_decompose(df['avg_price']) #period=period
        fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(14, 18), dpi=65)
        ax1.plot(result.observed, color='blue', linewidth=1)
        ax1.set_title('{0} original time series'.format(company_short))
        ax2.plot(result.trend, color='red', linewidth=1)
        ax2.set_title('Trend')
        # ax3.plot(result.seasonal, color='red', linewidth=1)
        # ax3.set_title('Seasonality')
        ax3.plot(result.resid, color='red', linewidth=1)
        ax3.set_title('Residuals')
        plt.xlabel('Date')
        plt.savefig(f'{ARIMA_PLOTS_PATH}/{self.experiment_name}_{company_short}_decomposition.png');
        #plt.show()
        plt.close(fig)

    def perform_df_test(self, timeseries, reg, autol, pval):
        """
        I choose AIC as autolag (more often used than BIC).
        I choose regression type (reg) as 'c' : constant only (default).
        """
        dftest = adfuller(timeseries, regression=reg, autolag=autol)
        # p_value = dftest[1]
        test_statistic = dftest[0]
        critical_value = dftest[4][pval]
        return test_statistic, critical_value

    def perform_first_difference(self, df, number_of_first_diff, company, company_short):
        try:
            if number_of_first_diff == 1:
                df['diff_price'] = df.avg_price.diff()
                df.drop('avg_price', axis=1, inplace=True)
            else:
                df.diff_price = df.diff_price.diff()
        except AttributeError:
            df['diff_price'] = df.avg_price.diff()
            df.drop('avg_price', axis=1, inplace=True)
        df = df.iloc[1:, :]
        df = df.reset_index(drop=True)
        fig = plt.figure(figsize=(14, 7), dpi=100)
        plt.plot(df['timestamp'], df['diff_price'], color='green', linewidth=1, linestyle='solid')
        plt.title("{0} after {1} first difference".format(company_short, number_of_first_diff))
        plt.xlabel('Date')
        plt.ylabel('Average price values after log and first diff')
        plt.legend(['{0}'.format(company_short)])
        plt.savefig(f'{ARIMA_PLOTS_PATH}/{self.experiment_name}_{company_short}_after_{number_of_first_diff}_first_difference.png');
        #plt.savefig(ARIMA_PLOTS_PATH + '/{0}_after_{1}_first_difference.png'.format(company, number_of_first_diff));
        # plt.show()
        plt.close(fig)
        return df

    def create_acf_pacf_charts(self, series, lags, datatype, company, company_short, use_pq=False, pq=(0, 0)):
        """
        Remember to ommit first tab ("wypustka"), because it's the correlation of the variable with itself.
        It can be ommited by using parameter zero=False.
        Documentation about plot_acf: https://www.statsmodels.org/dev/generated/statsmodels.graphics.tsaplots.plot_acf.html
        zero: bool, optional
        Flag indicating whether to include the 0-lag autocorrelation. Default is True.
        """
        # SET TEMPORARY PLOT STYLE
        plt.style.use('classic')
        plt.rcParams['figure.facecolor'] = 'white'
        # ACF
        fig = plt.figure(figsize=(12, 9), dpi=90)
        ax1 = fig.add_subplot(211)
        sm.graphics.tsa.plot_acf(series, lags=self.ljungbox_boxpierce_lags, zero=False, ax=ax1)  # residuals, fig2
        plt.ylabel('Value')
        plt.title('{0} {1} ACF'.format(company_short, datatype))
        # PACF
        ax2 = fig.add_subplot(212)
        sm.graphics.tsa.plot_pacf(series, lags=self.ljungbox_boxpierce_lags, zero=False, method="ywm",
                                  ax=ax2)  # residuals, fig3
        plt.ylabel('Value')
        plt.xlabel('Number of tabs')

        if use_pq:
            plt.savefig(
                f'{ARIMA_PLOTS_PATH}/{self.experiment_name}_{company_short}_{datatype}_p_{pq[0]}_q_{pq[1]}_plot_ACF_and_PACF.png');
        else:
            plt.savefig(f'{ARIMA_PLOTS_PATH}/{self.experiment_name}_{company_short}_{datatype}_plot_ACF_and_PACF.png');
        # plt.savefig(ARIMA_PLOTS_PATH + '/{0}_{1}_plot_ACF_and_PACF.png'.format(company, datatype));  # , bbox_inches=0
        # plt.show()
        plt.close(fig)
        # plt.close(fig2)
        # plt.close(fig3)
        # BACK TO DEFINED STYLE
        plt.style.use('fivethirtyeight')
        plt.style.use('seaborn-bright')

    def perform_ljungbox_boxpierce(self, df_price, p, d, q, lags):
        """
        Performs Ljung-Box and Box-Pierce tests. Check the residuals autocorrelations.
        https://www.statsmodels.org/stable/generated/statsmodels.stats.diagnostic.acorr_ljungbox.html
        Remember, that p, d, q values HAVE TO BE INTEGERS!!
        """
        res = sm.tsa.SARIMAX(endog=df_price, order=(p, d, q)).fit()  # transparams=False
        lb_bp_results = sm.stats.acorr_ljungbox(res.resid, lags=[lags], boxpierce=True) #return_df=True, 
        #display(lb_bp_results)
        #lb_p_value = lb_bp_results['lb_pvalue'].values[0]
        #bp_p_value = lb_bp_results['bp_pvalue'].values[0]
        lb_p_value = lb_bp_results[1]
        bp_p_value = lb_bp_results[3]
        residuals = res.resid
        return lb_p_value, bp_p_value, residuals

    def create_prediction_plot(self, df, train, test, fc_series, lower_series, upper_series, period, train_timestamp,
                               test_timestamp, company, company_short, p, d, q):
        # prepare xticks for plot
        # list_x_ticks = []
        # list_timestamps_x_ticks = []
        # final_year = df.timestamp[len(df)-1].year
        # for xtick in range(0, len(df) + round(len(df)/7), round(len(df)/7)):
        #    list_x_ticks.append(xtick)
        #    if xtick > len(df):
        #        list_timestamps_x_ticks.append(final_year + 2)
        #    else:
        #        list_timestamps_x_ticks.append(df.timestamp[xtick].year)

        # # prepare yticks for plot
        # list_y_ticks = []
        # # print(df.avg_price.min(), df.avg_price.max())
        # min_val = df.avg_price.min()
        # max_val = df.avg_price.max()
        # step = (max_val - min_val) / 9
        # # print("step:", step)
        # # print('\n')
        # for ytick in np.arange(min_val, max_val + step, step):
        #     #print(ytick)
        #     list_y_ticks.append(round(ytick, 2))
        # # print("list_y_ticks", list_y_ticks)
        #
        # # prepare y_exp_ticks for plot
        # list_exp_y_ticks = []
        # # print("df.avg_price.min()", df.avg_price.min(), "df.avg_price.max()", df.avg_price.max())
        # # print("exp(min_price)", np.exp(df.avg_price.min()), "exp(max_price)", np.exp(df.avg_price.max()))
        # min_val = np.exp(df.avg_price.min())
        # max_val = np.exp(df.avg_price.max())
        # step = (max_val - min_val) / 9
        # # print("step:", step)
        # # print('\n')
        # for ytick in np.arange(min_val, max_val + step, step):
        #     # print("ytick", ytick)
        #     list_exp_y_ticks.append(round(ytick, 2))
        # # print("list_exp_y_ticks", list_exp_y_ticks)

        # Plot
        # SET TEMPORARY PLOT STYLE
        plt.style.use('classic')
        plt.rcParams['figure.facecolor'] = 'white'

        fig = plt.figure(figsize=(12, 7), dpi=90)

        plt.plot(train_timestamp, train, label='training', linewidth=1, color='b')  # train.index
        plt.plot(test_timestamp, test, label='actual', linewidth=1, color='g')  # test.index
        plt.plot(test_timestamp, fc_series, label='forecast', linewidth=1, color='r')  # fc_series.index

        plt.fill_between(test_timestamp, lower_series, upper_series, color='k', alpha=.15)  # lower_series.index,

        plt.title(f'Forecast vs Actuals for {company_short} forecast period = {period}')
        plt.legend(loc='upper left', fontsize=8)
        plt.xlabel('Time [years]')
        plt.ylabel('Real value [\$]')
        # plt.xticks(list_x_ticks, list_timestamps_x_ticks, rotation = 45)
        #plt.yticks(list_y_ticks, list_exp_y_ticks) #, color="red"
        plt.savefig(f'{ARIMA_PLOTS_PATH}/{self.experiment_name}_{company_short}_period_{period}_ARIMA({p}{d}{q})_prediction_plot.png');
        #plt.savefig(ARIMA_PLOTS_PATH + '/{0}_ARIMA_prediction_plot.png'.format(company))
        # plt.show()
        plt.close(fig)
        #################################################

    def create_zoomed_prediction_plot(self, df, test, fc_series, lower_series, upper_series, period, test_timestamp,
                                      company, company_short, p, d, q):
        # prepare yticks
        # minimum_value = lower_series.values.min()
        # maximum_value = upper_series.values.max()
        # minimum_value = min(lower_series)
        # maximum_value = max(upper_series)
        # # print("min value", minimum_value, "max value", maximum_value)
        #
        # # prepare yticks for plot
        # list_y_ticks = []
        # # display(minimum_value, maximum_value)
        # min_val = round(minimum_value, 2)
        # max_val = round(maximum_value, 2)
        # # print("min value", min_val, "max value", max_val)
        # step = round((max_val - min_val) / 20, 2)
        # # print("step:", step)
        # # print('\n')
        # for ytick in np.arange(min_val, max_val + step, step):
        #     # print(ytick)
        #     list_y_ticks.append(round(ytick, 2))
        # # print("final y list", list_y_ticks)
        #
        # # prepare y_exp_ticks for plot
        # list_exp_y_ticks = []
        # # print("min value", minimum_value, "max value", maximum_value)
        # min_val = round(np.exp(minimum_value), 2)
        # max_val = round(np.exp(maximum_value), 2)
        # # print("min exp value", min_val, "max exp value", max_val)
        # step = round((max_val - min_val) / 20, 2)
        # # print("step:", step)
        # # print('\n')
        # for ytick in np.arange(min_val, max_val, step):
        #     # print(ytick)
        #     list_exp_y_ticks.append(round(ytick, 2))
        # # print("final y exp list", list_exp_y_ticks)

        # PLOT
        fig = plt.figure(figsize=(12, 7), dpi=90)
        ax3 = plt.subplot(111)
        plt.plot(test_timestamp, test, label='actual', linewidth=2, color='g')  # test.index
        plt.plot(test_timestamp, fc_series, label='forecast', linewidth=2, color='r')
        plt.fill_between(test_timestamp, lower_series, upper_series, color='k', alpha=.15)

        # ax3.margins(x=-0.49, y=-0.25)
        # ax3.xaxis.zoom(4)
        plt.title(f'Forecast vs Actuals for {company_short} forecast period = {period}')
        plt.legend(loc='upper left', fontsize=8)
        plt.xticks(rotation=45)
        # plt.xticks(list_x_ticks, list_timestamps_x_ticks, rotation = 45)
        # plt.yticks(list_y_ticks[:-1], list_exp_y_ticks[:-1]) #, color="red"
        #plt.yticks(list_y_ticks, list_exp_y_ticks)
        plt.ylabel('Real value [\$]')
        plt.xlabel('Date')
        # plt.xlim(2019, 2021)
        plt.tight_layout()  # in order not to cut bottom part of plot in saved one
        plt.savefig(f'{ARIMA_PLOTS_PATH}/{self.experiment_name}_{company_short}_period_{period}_ARIMA({p}{d}{q})_zoomed_prediction_plot.png');
        #plt.savefig(ARIMA_PLOTS_PATH + '/{0}_ARIMA_zoomed_prediction_plot.png'.format(company))
        # plt.show()
        plt.close(fig)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
np.ndarray([1])[0]
# Out:
# 2.5e-323
